# %%
import seaborn as sns
import pandas as pd
import matplotlib as plt
#import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from pandas_profiling import ProfileReport
import sklearn.metrics as metrics
print("Libraries Loaded!")
# Out:
# Libraries Loaded!

# %% [markdown]
# What is a Logit? A Logit function, also known as the log-odds function, is a function that represents probability values from 0 to 1, and negative infinity to infinity. The function is an inverse to the sigmoid function that limits values between 0 and 1 across the Y-axis, rather than the X-axis.
#
# MLE (Maximum likelihood estimation) -

# %%
df = pd.csv_read(".csv")

profile = ProfileReport(df)
profile.to_widgets()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\3207951352.py in <module>
# ----> 1 df = pd.csv_read(".csv")
#       2
#       3 profile = ProfileReport(df)
#       4 profile.to_widgets()
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'csv_read'

# %%
#selecting the columns, I am supposing the data is already cleaned as it should be before entering a model
x = df[["Column1"]]
y = df[["Column2"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\1319401565.py in <module>
#       1 #selecting the columns, I am supposing the data is already cleaned as it should be before entering a model
# ----> 2 x = df[["Column1"]]
#       3 y = df[["Column2"]]
#
# NameError: name 'df' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size= 0.3 , random_state=42)
clf = LogisticRegression().fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\2420837525.py in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(x,y, test_size= 0.3 , random_state=42)
#       2 clf = LogisticRegression().fit(X_train,y_train)
#
# NameError: name 'x' is not defined

# %%
#coefficient of the ecuation
clf.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\2934205355.py in <module>
# ----> 1 clf.coef_
#
# NameError: name 'clf' is not defined

# %%
#interception of the ecuation
clf.intercept_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\3046031642.py in <module>
# ----> 1 clf.intercept_
#
# NameError: name 'clf' is not defined

# %%
sns.regplot(x="Column1",y="Column2", data=df, logistic=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\1623021446.py in <module>
# ----> 1 sns.regplot(x="Column1",y="Column2", data=df, logistic=True)
#
# NameError: name 'df' is not defined

# %%
#Saving predictions for testing
y_pred = clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\1747830821.py in <module>
#       1 #Saving predictions for testing
# ----> 2 y_pred = clf.predict(x_test)
#
# NameError: name 'clf' is not defined

# %%
#matrix of probabilites
clf.predict_proba(X_test)[::,-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\3909633195.py in <module>
# ----> 1 clf.predict_proba(X_test)[::,-1]
#
# NameError: name 'clf' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
#T means True, F of False, P of positive, N of negatives.
cm = metrics.confusion_metrix(y_test, y_pred, labels = clf.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = clf.classes_)
disp.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\541987146.py in <module>
# ----> 1 disp = metrics.ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = clf.classes_)
#
# NameError: name 'metrics' is not defined

# %%
#Precision (proportion of positivies that were true positives) TP/(TP+FP)
metrics.precision_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\3909593783.py in <module>
#       1 #Precision
# ----> 2 metrics.precision_score(y_test,y_pred)
#
# NameError: name 'metrics' is not defined

# %%
#Recall (proportion of positivies that were identified correctly) TP/(TP+FN)
metrics.recall_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\1894220352.py in <module>
# ----> 1 metrics.recall_score(y_test,y_pred)
#
# NameError: name 'metrics' is not defined

# %%
#Accuracy (proportion of data that were correctly categorized) (TP+TN)/Total Predictions
metrics.accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\2262362884.py in <module>
#       1 #Accuracy (proportion of data that were correctly categorized) (TP+TN)/Total Predictions
# ----> 2 metrics.accuracy_score(y_test,y_pred)
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# ### Remember the consecuencies of moving thresholds
# # Its recommended to use ROC curve to analyze the threshold
# ![image.png](attachment:image.png)
#
# You can examine an ROC curve to observe how the False Positive Rate and True Positive Rate change together over the different thresholds. In the ROC curve for an ideal model, there would exist a threshold at which the True Positive Rate is high and the False Positive Rate is low. The more that the ROC curve hugs the top left corner of the plot, the better the model does at classifying the data.
#
#
# ![image-3.png](attachment:image-3.png)

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(y_test, y_pred)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31392\914327570.py in <module>
#       1 from sklearn.metrics import RocCurveDisplay
# ----> 2 RocCurveDisplay.from_predictions(y_test, y_pred)
#       3 plt.show()
#       4
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# ### understanding even more (Using the AUC)
# AUC stands for area under the ROC curve. AUC provides an aggregate measure of performance across all possible
# classification thresholds. AUC ranges in value from 0.0 to 1.0. A model whose predictions are 100% wrong has
# an AUC of 0.0, and a model whose predictions are 100% correct has an AUC of 1.0. An AUC smaller than 0.5 indicates
# that the model performs worse than a random classifier (i.e. a classifier that randomly assigns each example to
# True or False), and an AUC larger than 0.5 indicates that the model performs better than a random classifier.
# ![image.png](attachment:image.png)

# %%
# Easy example> 
#For example, in the context of a logistic regression classifier for email spam detection, 
#if the roc_auc_score() function returns 0.99, that means 99% of the classifier’s predictions 
#are correct across all classification thresholds.  
metrics.roc_auc_score(y_test,y_pred))
# Out:
#   File "C:\Users\JoseLuis\AppData\Local\Temp\ipykernel_31392\2289890826.py", line 5
#     metrics.roc_auc_score(y_test,y_pred))
#                                         ^
# SyntaxError: unmatched ')'
